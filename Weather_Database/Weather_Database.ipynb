# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests
import random
from config import weather_api_key
import time
from datetime import datetime

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Creat an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval      ")
print("------------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, amd set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 1 | lompoc
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 1 | saint george
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | hervey bay
# Processing Record 10 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 11 of Set 1 | pangai
# Processing Record 12 of Set 1 | vrangel
# Processing Record 13 of Set 1 | dikson
# Processing Record 14 of Set 1 | faanui
# Processing Record 15 of Set 1 | narsaq
# Processing Record 16 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | dubbo
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | bambous virieux
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | arraial do cabo
# Processing Record 23 of Set 1 | mar del plata
# Processing Record 24 of Set 1 | waipawa
# Processing Record 25 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | hasaki
# Processing Record 28 of Set 1 | coahuayana
# Processing Record 29 of Set 1 | bend
# Processing Record 30 of Set 1 | tomioka
# Processing Record 31 of Set 1 | prado
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | gacko
# Processing Record 34 of Set 1 | mahebourg
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | victoria
# Processing Record 39 of Set 1 | nikolskoye
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | oktyabrskoye
# Processing Record 42 of Set 1 | yeppoon
# Processing Record 43 of Set 1 | fatsa
# Processing Record 44 of Set 1 | saint-pierre
# Processing Record 45 of Set 1 | new norfolk
# Processing Record 46 of Set 1 | viransehir
# Processing Record 47 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 1 | barroualie
# City not found. Skipping...
# Processing Record 49 of Set 1 | biak
# Processing Record 50 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | kruisfontein
# Processing Record 4 of Set 2 | ankazobe
# Processing Record 5 of Set 2 | kalmunai
# Processing Record 6 of Set 2 | luderitz
# Processing Record 7 of Set 2 | general salgado
# Processing Record 8 of Set 2 | homer
# Processing Record 9 of Set 2 | palmer
# Processing Record 10 of Set 2 | banda aceh
# Processing Record 11 of Set 2 | atuona
# Processing Record 12 of Set 2 | puerto ayora
# Processing Record 13 of Set 2 | maposeni
# Processing Record 14 of Set 2 | mehamn
# Processing Record 15 of Set 2 | beira
# Processing Record 16 of Set 2 | kodiak
# Processing Record 17 of Set 2 | dudinka
# Processing Record 18 of Set 2 | sohag
# Processing Record 19 of Set 2 | saldanha
# Processing Record 20 of Set 2 | saint-philippe
# Processing Record 21 of Set 2 | east london
# Processing Record 22 of Set 2 | tezu
# Processing Record 23 of Set 2 | cap malheureux
# Processing Record 24 of Set 2 | tiznit
# Processing Record 25 of Set 2 | tasiilaq
# Processing Record 26 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 2 | gulshat
# City not found. Skipping...
# Processing Record 28 of Set 2 | virginia beach
# Processing Record 29 of Set 2 | sabya
# Processing Record 30 of Set 2 | geilo
# Processing Record 31 of Set 2 | esperance
# Processing Record 32 of Set 2 | salalah
# Processing Record 33 of Set 2 | samagaltay
# Processing Record 34 of Set 2 | hithadhoo
# Processing Record 35 of Set 2 | bay roberts
# Processing Record 36 of Set 2 | zhigansk
# Processing Record 37 of Set 2 | tateyama
# Processing Record 38 of Set 2 | pamekasan
# Processing Record 39 of Set 2 | gat
# Processing Record 40 of Set 2 | constitucion
# Processing Record 41 of Set 2 | pevek
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | pingtung
# Processing Record 44 of Set 2 | provideniya
# Processing Record 45 of Set 2 | hondo
# Processing Record 46 of Set 2 | beloha
# Processing Record 47 of Set 2 | kavieng
# Processing Record 48 of Set 2 | nizhnevartovsk
# Processing Record 49 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 2 | airai
# Processing Record 1 of Set 3 | hohhot
# Processing Record 2 of Set 3 | magalia
# Processing Record 3 of Set 3 | salekhard
# Processing Record 4 of Set 3 | bredasdorp
# Processing Record 5 of Set 3 | cayenne
# Processing Record 6 of Set 3 | lushunkou
# City not found. Skipping...
# Processing Record 7 of Set 3 | veraval
# Processing Record 8 of Set 3 | kokkola
# Processing Record 9 of Set 3 | ahuimanu
# Processing Record 10 of Set 3 | balakhninskiy
# Processing Record 11 of Set 3 | kaitangata
# Processing Record 12 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 13 of Set 3 | savannah bight
# Processing Record 14 of Set 3 | ust-barguzin
# Processing Record 15 of Set 3 | pecos
# Processing Record 16 of Set 3 | tuktoyaktuk
# Processing Record 17 of Set 3 | yuanping
# Processing Record 18 of Set 3 | palaikastron
# Processing Record 19 of Set 3 | grand forks
# Processing Record 20 of Set 3 | te anau
# Processing Record 21 of Set 3 | porto belo
# Processing Record 22 of Set 3 | koygorodok
# Processing Record 23 of Set 3 | yellowknife
# Processing Record 24 of Set 3 | mana
# Processing Record 25 of Set 3 | ponta do sol
# Processing Record 26 of Set 3 | shenjiamen
# Processing Record 27 of Set 3 | isangel
# Processing Record 28 of Set 3 | tlahualilo
# City not found. Skipping...
# Processing Record 29 of Set 3 | jasper
# Processing Record 30 of Set 3 | wagar
# Processing Record 31 of Set 3 | vaini
# Processing Record 32 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 3 | jamestown
# Processing Record 34 of Set 3 | camacha
# Processing Record 35 of Set 3 | mwinilunga
# Processing Record 36 of Set 3 | bolshaya orlovka
# City not found. Skipping...
# Processing Record 37 of Set 3 | ndele
# Processing Record 38 of Set 3 | shetpe
# Processing Record 39 of Set 3 | georgetown
# Processing Record 40 of Set 3 | tura
# Processing Record 41 of Set 3 | areka
# Processing Record 42 of Set 3 | khor
# Processing Record 43 of Set 3 | henties bay
# Processing Record 44 of Set 3 | westport
# Processing Record 45 of Set 3 | ribeira grande
# Processing Record 46 of Set 3 | churapcha
# Processing Record 47 of Set 3 | cidreira
# Processing Record 48 of Set 3 | lumeje
# Processing Record 49 of Set 3 | batemans bay
# Processing Record 50 of Set 3 | sakakah
# Processing Record 1 of Set 4 | sayyan
# Processing Record 2 of Set 4 | kavaratti
# Processing Record 3 of Set 4 | codrington
# Processing Record 4 of Set 4 | bilma
# Processing Record 5 of Set 4 | lannion
# Processing Record 6 of Set 4 | chokurdakh
# Processing Record 7 of Set 4 | kuliyapitiya
# Processing Record 8 of Set 4 | ico
# Processing Record 9 of Set 4 | bethel
# Processing Record 10 of Set 4 | mitsamiouli
# Processing Record 11 of Set 4 | hualmay
# Processing Record 12 of Set 4 | puerto escondido
# Processing Record 13 of Set 4 | nanortalik
# Processing Record 14 of Set 4 | pangkalanbuun
# Processing Record 15 of Set 4 | olafsvik
# Processing Record 16 of Set 4 | kibray
# Processing Record 17 of Set 4 | kolokani
# Processing Record 18 of Set 4 | avarua
# Processing Record 19 of Set 4 | khatanga
# Processing Record 20 of Set 4 | luena
# Processing Record 21 of Set 4 | whitehorse
# Processing Record 22 of Set 4 | lebu
# Processing Record 23 of Set 4 | nouadhibou
# Processing Record 24 of Set 4 | codajas
# Processing Record 25 of Set 4 | outlook
# Processing Record 26 of Set 4 | carnarvon
# Processing Record 27 of Set 4 | marawi
# Processing Record 28 of Set 4 | fortuna
# Processing Record 29 of Set 4 | pisco
# Processing Record 30 of Set 4 | nurota
# Processing Record 31 of Set 4 | leua
# Processing Record 32 of Set 4 | bandarbeyla
# Processing Record 33 of Set 4 | sur
# Processing Record 34 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 4 | mindif
# Processing Record 37 of Set 4 | tonantins
# Processing Record 38 of Set 4 | panalingaan
# Processing Record 39 of Set 4 | inyonga
# Processing Record 40 of Set 4 | adre
# Processing Record 41 of Set 4 | benghazi
# Processing Record 42 of Set 4 | taoudenni
# Processing Record 43 of Set 4 | moose factory
# Processing Record 44 of Set 4 | saquarema
# Processing Record 45 of Set 4 | guerrero negro
# Processing Record 46 of Set 4 | qaanaaq
# Processing Record 47 of Set 4 | jumla
# Processing Record 48 of Set 4 | abeche
# Processing Record 49 of Set 4 | quang ngai
# Processing Record 50 of Set 4 | thompson
# Processing Record 1 of Set 5 | upernavik
# Processing Record 2 of Set 5 | colares
# Processing Record 3 of Set 5 | belturbet
# Processing Record 4 of Set 5 | san patricio
# Processing Record 5 of Set 5 | shaowu
# Processing Record 6 of Set 5 | broome
# Processing Record 7 of Set 5 | aklavik
# Processing Record 8 of Set 5 | seoul
# Processing Record 9 of Set 5 | nyurba
# Processing Record 10 of Set 5 | healesville
# Processing Record 11 of Set 5 | corinto
# Processing Record 12 of Set 5 | porto novo
# Processing Record 13 of Set 5 | vardo
# Processing Record 14 of Set 5 | pochutla
# Processing Record 15 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 5 | port elizabeth
# Processing Record 17 of Set 5 | geraldton
# Processing Record 18 of Set 5 | oistins
# Processing Record 19 of Set 5 | mount gambier
# Processing Record 20 of Set 5 | scottsburgh
# City not found. Skipping...
# Processing Record 21 of Set 5 | zyryanka
# Processing Record 22 of Set 5 | umea
# Processing Record 23 of Set 5 | merauke
# Processing Record 24 of Set 5 | baculin
# Processing Record 25 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 5 | udachnyy
# Processing Record 27 of Set 5 | embu
# Processing Record 28 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 29 of Set 5 | adrar
# Processing Record 30 of Set 5 | murindo
# Processing Record 31 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 32 of Set 5 | helena
# Processing Record 33 of Set 5 | sudbury
# Processing Record 34 of Set 5 | laguna
# Processing Record 35 of Set 5 | severo-kurilsk
# Processing Record 36 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 5 | aksu
# Processing Record 38 of Set 5 | poum
# Processing Record 39 of Set 5 | carutapera
# Processing Record 40 of Set 5 | klaksvik
# Processing Record 41 of Set 5 | saint-georges
# Processing Record 42 of Set 5 | hargeysa
# Processing Record 43 of Set 5 | ardakan
# Processing Record 44 of Set 5 | eureka
# Processing Record 45 of Set 5 | torbay
# Processing Record 46 of Set 5 | alice springs
# Processing Record 47 of Set 5 | muroto
# Processing Record 48 of Set 5 | bubaque
# Processing Record 49 of Set 5 | berkak
# Processing Record 50 of Set 5 | collie
# Processing Record 1 of Set 6 | coihaique
# Processing Record 2 of Set 6 | longyearbyen
# Processing Record 3 of Set 6 | mopti
# Processing Record 4 of Set 6 | hofn
# Processing Record 5 of Set 6 | sembakung
# Processing Record 6 of Set 6 | oeiras
# Processing Record 7 of Set 6 | port lincoln
# Processing Record 8 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 6 | tandalti
# Processing Record 10 of Set 6 | namibe
# Processing Record 11 of Set 6 | sola
# Processing Record 12 of Set 6 | lashio
# Processing Record 13 of Set 6 | moranbah
# Processing Record 14 of Set 6 | shelburne
# Processing Record 15 of Set 6 | khash
# Processing Record 16 of Set 6 | tiksi
# Processing Record 17 of Set 6 | grand gaube
# Processing Record 18 of Set 6 | bugiri
# Processing Record 19 of Set 6 | makushino
# Processing Record 20 of Set 6 | korla
# Processing Record 21 of Set 6 | terney
# Processing Record 22 of Set 6 | mpongwe
# Processing Record 23 of Set 6 | haines junction
# Processing Record 24 of Set 6 | winslow
# Processing Record 25 of Set 6 | asayita
# City not found. Skipping...
# Processing Record 26 of Set 6 | pacific grove
# Processing Record 27 of Set 6 | mandalgovi
# Processing Record 28 of Set 6 | barrow
# Processing Record 29 of Set 6 | eyl
# Processing Record 30 of Set 6 | santa rosa
# Processing Record 31 of Set 6 | gus-zheleznyy
# Processing Record 32 of Set 6 | port hardy
# Processing Record 33 of Set 6 | ancud
# Processing Record 34 of Set 6 | burica
# City not found. Skipping...
# Processing Record 35 of Set 6 | rocha
# Processing Record 36 of Set 6 | kloulklubed
# Processing Record 37 of Set 6 | porbandar
# Processing Record 38 of Set 6 | rivne
# Processing Record 39 of Set 6 | ilulissat
# Processing Record 40 of Set 6 | itupiranga
# Processing Record 41 of Set 6 | songkhla
# Processing Record 42 of Set 6 | taman
# Processing Record 43 of Set 6 | ambanja
# Processing Record 44 of Set 6 | chara
# Processing Record 45 of Set 6 | berga
# Processing Record 46 of Set 6 | ostrovnoy
# Processing Record 47 of Set 6 | paamiut
# Processing Record 48 of Set 6 | pontianak
# Processing Record 49 of Set 6 | soria
# Processing Record 50 of Set 6 | sao joao da barra
# Processing Record 1 of Set 7 | morant bay
# Processing Record 2 of Set 7 | saskylakh
# Processing Record 3 of Set 7 | doka
# Processing Record 4 of Set 7 | niquero
# Processing Record 5 of Set 7 | rostovka
# Processing Record 6 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 7 of Set 7 | abu kamal
# Processing Record 8 of Set 7 | brigantine
# Processing Record 9 of Set 7 | emerald
# Processing Record 10 of Set 7 | samarai
# Processing Record 11 of Set 7 | avera
# Processing Record 12 of Set 7 | katsuura
# Processing Record 13 of Set 7 | dubno
# Processing Record 14 of Set 7 | sept-iles
# Processing Record 15 of Set 7 | kumba
# Processing Record 16 of Set 7 | akyab
# Processing Record 17 of Set 7 | shaoguan
# Processing Record 18 of Set 7 | fort saint james
# Processing Record 19 of Set 7 | talnakh
# Processing Record 20 of Set 7 | kindu
# Processing Record 21 of Set 7 | vendome
# Processing Record 22 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 23 of Set 7 | roald
# Processing Record 24 of Set 7 | tautira
# Processing Record 25 of Set 7 | iqaluit
# Processing Record 26 of Set 7 | manacapuru
# Processing Record 27 of Set 7 | terrace bay
# Processing Record 28 of Set 7 | ponta delgada
# Processing Record 29 of Set 7 | malayal
# Processing Record 30 of Set 7 | tocopilla
# Processing Record 31 of Set 7 | esna
# Processing Record 32 of Set 7 | rawson
# Processing Record 33 of Set 7 | ahipara
# Processing Record 34 of Set 7 | islampur
# Processing Record 35 of Set 7 | berlevag
# Processing Record 36 of Set 7 | destin
# Processing Record 37 of Set 7 | vostok
# Processing Record 38 of Set 7 | saint-joseph
# Processing Record 39 of Set 7 | itarema
# Processing Record 40 of Set 7 | lufilufi
# Processing Record 41 of Set 7 | quesnel
# Processing Record 42 of Set 7 | pangnirtung
# Processing Record 43 of Set 7 | chuguyevka
# Processing Record 44 of Set 7 | falam
# Processing Record 45 of Set 7 | ciro marina
# Processing Record 46 of Set 7 | harper
# Processing Record 47 of Set 7 | awbari
# Processing Record 48 of Set 7 | olenino
# Processing Record 49 of Set 7 | vanavara
# Processing Record 50 of Set 7 | sioux lookout
# Processing Record 1 of Set 8 | praya
# Processing Record 2 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 3 of Set 8 | naryan-mar
# Processing Record 4 of Set 8 | san cristobal
# Processing Record 5 of Set 8 | niscemi
# Processing Record 6 of Set 8 | kenai
# Processing Record 7 of Set 8 | ukiah
# Processing Record 8 of Set 8 | yulara
# Processing Record 9 of Set 8 | san andres
# Processing Record 10 of Set 8 | leningradskiy
# Processing Record 11 of Set 8 | bathsheba
# Processing Record 12 of Set 8 | flinders
# Processing Record 13 of Set 8 | kamenka
# Processing Record 14 of Set 8 | hay river
# Processing Record 15 of Set 8 | dickinson
# Processing Record 16 of Set 8 | togur
# Processing Record 17 of Set 8 | oksfjord
# Processing Record 18 of Set 8 | kalabo
# Processing Record 19 of Set 8 | barcelos
# Processing Record 20 of Set 8 | vila velha
# Processing Record 21 of Set 8 | leshan
# Processing Record 22 of Set 8 | portland
# Processing Record 23 of Set 8 | safwah
# City not found. Skipping...
# Processing Record 24 of Set 8 | ust-tsilma
# Processing Record 25 of Set 8 | dondo
# Processing Record 26 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 27 of Set 8 | biltine
# Processing Record 28 of Set 8 | tilichiki
# Processing Record 29 of Set 8 | ruteng
# Processing Record 30 of Set 8 | phu ly
# Processing Record 31 of Set 8 | atasu
# Processing Record 32 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 33 of Set 8 | pudozh
# Processing Record 34 of Set 8 | kahului
# Processing Record 35 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 8 | la palma
# Processing Record 37 of Set 8 | kijang
# Processing Record 38 of Set 8 | auki
# Processing Record 39 of Set 8 | gushikawa
# Processing Record 40 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 41 of Set 8 | yerbogachen
# Processing Record 42 of Set 8 | saint-gaudens
# Processing Record 43 of Set 8 | puerto el triunfo
# Processing Record 44 of Set 8 | necochea
# Processing Record 45 of Set 8 | cherskiy
# Processing Record 46 of Set 8 | elat
# Processing Record 47 of Set 8 | sabha
# Processing Record 48 of Set 8 | ayagoz
# Processing Record 49 of Set 8 | verkhnyaya toyma
# Processing Record 50 of Set 8 | jiuquan
# Processing Record 1 of Set 9 | tawnat
# City not found. Skipping...
# Processing Record 2 of Set 9 | mezhdurechensk
# Processing Record 3 of Set 9 | carballo
# Processing Record 4 of Set 9 | orlik
# Processing Record 5 of Set 9 | zhangye
# Processing Record 6 of Set 9 | cabra
# Processing Record 7 of Set 9 | bulgan
# Processing Record 8 of Set 9 | ulaanbaatar
# Processing Record 9 of Set 9 | fukue
# Processing Record 10 of Set 9 | verkhnyaya inta
# Processing Record 11 of Set 9 | wexford
# Processing Record 12 of Set 9 | sitka
# Processing Record 13 of Set 9 | kurumkan
# Processing Record 14 of Set 9 | college
# Processing Record 15 of Set 9 | borogontsy
# Processing Record 16 of Set 9 | ishigaki
# Processing Record 17 of Set 9 | molfetta
# Processing Record 18 of Set 9 | marsa matruh
# Processing Record 19 of Set 9 | raudeberg
# Processing Record 20 of Set 9 | naze
# Processing Record 21 of Set 9 | ha
# City not found. Skipping...
# Processing Record 22 of Set 9 | pascagoula
# Processing Record 23 of Set 9 | djambala
# Processing Record 24 of Set 9 | hit
# Processing Record 25 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 9 | banfora
# Processing Record 27 of Set 9 | canatlan
# Processing Record 28 of Set 9 | camara de lobos
# Processing Record 29 of Set 9 | guarapari
# Processing Record 30 of Set 9 | makung
# City not found. Skipping...
# Processing Record 31 of Set 9 | ambon
# Processing Record 32 of Set 9 | ca mau
# Processing Record 33 of Set 9 | half moon bay
# Processing Record 34 of Set 9 | mahon
# Processing Record 35 of Set 9 | huilong
# Processing Record 36 of Set 9 | dano
# Processing Record 37 of Set 9 | karratha
# Processing Record 38 of Set 9 | sao filipe
# Processing Record 39 of Set 9 | tukrah
# Processing Record 40 of Set 9 | bairiki
# Processing Record 41 of Set 9 | dunedin
# Processing Record 42 of Set 9 | bengkulu
# Processing Record 43 of Set 9 | atbasar
# Processing Record 44 of Set 9 | wewak
# Processing Record 45 of Set 9 | lorengau
# Processing Record 46 of Set 9 | madimba
# Processing Record 47 of Set 9 | hamilton
# Processing Record 48 of Set 9 | grindavik
# Processing Record 49 of Set 9 | olinda
# Processing Record 50 of Set 9 | punuare
# Processing Record 1 of Set 10 | jardim
# Processing Record 2 of Set 10 | ola
# Processing Record 3 of Set 10 | alyangula
# Processing Record 4 of Set 10 | alenquer
# Processing Record 5 of Set 10 | wajid
# Processing Record 6 of Set 10 | nkayi
# Processing Record 7 of Set 10 | olkhovatka
# Processing Record 8 of Set 10 | roma
# Processing Record 9 of Set 10 | golden
# Processing Record 10 of Set 10 | clyde river
# Processing Record 11 of Set 10 | cuyo
# Processing Record 12 of Set 10 | shingu
# Processing Record 13 of Set 10 | kachikau
# City not found. Skipping...
# Processing Record 14 of Set 10 | kaoma
# Processing Record 15 of Set 10 | sangar
# Processing Record 16 of Set 10 | grajau
# Processing Record 17 of Set 10 | onega
# Processing Record 18 of Set 10 | souillac
# Processing Record 19 of Set 10 | hangu
# Processing Record 20 of Set 10 | puerto leguizamo
# Processing Record 21 of Set 10 | edea
# Processing Record 22 of Set 10 | baker city
# Processing Record 23 of Set 10 | port keats
# Processing Record 24 of Set 10 | anadyr
# Processing Record 25 of Set 10 | danville
# Processing Record 26 of Set 10 | rapid valley
# Processing Record 27 of Set 10 | port blair
# Processing Record 28 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 10 | derzhavinsk
# Processing Record 30 of Set 10 | griffith
# Processing Record 31 of Set 10 | vanimo
# Processing Record 32 of Set 10 | kishtwar
# Processing Record 33 of Set 10 | midland
# Processing Record 34 of Set 10 | alta
# Processing Record 35 of Set 10 | pestravka
# Processing Record 36 of Set 10 | cloquet
# Processing Record 37 of Set 10 | fez
# Processing Record 38 of Set 10 | port-gentil
# Processing Record 39 of Set 10 | vila franca do campo
# Processing Record 40 of Set 10 | san borja
# Processing Record 41 of Set 10 | sakaiminato
# Processing Record 42 of Set 10 | odesskoye
# Processing Record 43 of Set 10 | gao
# Processing Record 44 of Set 10 | oranjemund
# Processing Record 45 of Set 10 | kupang
# Processing Record 46 of Set 10 | zalantun
# Processing Record 47 of Set 10 | kashi
# Processing Record 48 of Set 10 | simbahan
# Processing Record 49 of Set 10 | lishan
# Processing Record 50 of Set 10 | san quintin
# Processing Record 1 of Set 11 | roebourne
# Processing Record 2 of Set 11 | san policarpo
# Processing Record 3 of Set 11 | ewa beach
# Processing Record 4 of Set 11 | korce
# Processing Record 5 of Set 11 | amalapuram
# Processing Record 6 of Set 11 | maniitsoq
# Processing Record 7 of Set 11 | tibati
# Processing Record 8 of Set 11 | tutoia
# Processing Record 9 of Set 11 | antofagasta
# Processing Record 10 of Set 11 | nishihara
# Processing Record 11 of Set 11 | atikokan
# Processing Record 12 of Set 11 | aswan
# Processing Record 13 of Set 11 | richards bay
# Processing Record 14 of Set 11 | phanom thuan
# Processing Record 15 of Set 11 | puerto baquerizo moreno
# Processing Record 16 of Set 11 | tessalit
# Processing Record 17 of Set 11 | houston
# Processing Record 18 of Set 11 | koumac
# Processing Record 19 of Set 11 | waingapu
# Processing Record 20 of Set 11 | ribeira brava
# Processing Record 21 of Set 11 | xocali
# Processing Record 22 of Set 11 | minbu
# Processing Record 23 of Set 11 | lichinga
# Processing Record 24 of Set 11 | yomitan
# City not found. Skipping...
# Processing Record 25 of Set 11 | byron bay
# Processing Record 26 of Set 11 | vao
# Processing Record 27 of Set 11 | chuy
# Processing Record 28 of Set 11 | gorshechnoye
# Processing Record 29 of Set 11 | hobyo
# Processing Record 30 of Set 11 | oswego
# Processing Record 31 of Set 11 | eskilstuna
# Processing Record 32 of Set 11 | hovd
# Processing Record 33 of Set 11 | dongsheng
# Processing Record 34 of Set 11 | westerland
# Processing Record 35 of Set 11 | norman wells
# Processing Record 36 of Set 11 | tambun
# Processing Record 37 of Set 11 | maxixe
# Processing Record 38 of Set 11 | san jose
# Processing Record 39 of Set 11 | rio gallegos
# Processing Record 40 of Set 11 | nushki
# Processing Record 41 of Set 11 | butembo
# Processing Record 42 of Set 11 | nerchinskiy zavod
# Processing Record 43 of Set 11 | saint anthony
# Processing Record 44 of Set 11 | wanaka
# Processing Record 45 of Set 11 | muros
# Processing Record 46 of Set 11 | bilibino
# Processing Record 47 of Set 11 | chabahar
# Processing Record 48 of Set 11 | virar
# Processing Record 49 of Set 11 | denpasar
# Processing Record 50 of Set 11 | marzuq
# Processing Record 1 of Set 12 | isabela
# Processing Record 2 of Set 12 | edd
# Processing Record 3 of Set 12 | jalu
# Processing Record 4 of Set 12 | songea
# Processing Record 5 of Set 12 | huron
# Processing Record 6 of Set 12 | atsipopoulon
# Processing Record 7 of Set 12 | xuddur
# Processing Record 8 of Set 12 | beringovskiy
# Processing Record 9 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 12 | ixtapa
# Processing Record 11 of Set 12 | tigzirt
# Processing Record 12 of Set 12 | noumea
# Processing Record 13 of Set 12 | coquimbo
# Processing Record 14 of Set 12 | armidale
# Processing Record 15 of Set 12 | totness
# Processing Record 16 of Set 12 | nantucket
# Processing Record 17 of Set 12 | honiara
# Processing Record 18 of Set 12 | kieta
# Processing Record 19 of Set 12 | kalur kot
# Processing Record 20 of Set 12 | monrovia
# Processing Record 21 of Set 12 | moron
# Processing Record 22 of Set 12 | abhar
# Processing Record 23 of Set 12 | kumluca
# Processing Record 24 of Set 12 | khon kaen
# Processing Record 25 of Set 12 | lagoa
# Processing Record 26 of Set 12 | storsteinnes
# Processing Record 27 of Set 12 | macomb
# Processing Record 28 of Set 12 | port augusta
# Processing Record 29 of Set 12 | tabialan
# City not found. Skipping...
# Processing Record 30 of Set 12 | vung tau
# Processing Record 31 of Set 12 | thinadhoo
# Processing Record 32 of Set 12 | mattru
# Processing Record 33 of Set 12 | seybaplaya
# Processing Record 34 of Set 12 | hadejia
# Processing Record 35 of Set 12 | poya
# Processing Record 36 of Set 12 | miranorte
# City not found. Skipping...
# Processing Record 37 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 12 | amapa
# Processing Record 39 of Set 12 | margate
# Processing Record 40 of Set 12 | port macquarie
# Processing Record 41 of Set 12 | stornoway
# Processing Record 42 of Set 12 | padang
# Processing Record 43 of Set 12 | podolinec
# Processing Record 44 of Set 12 | lahaina
# Processing Record 45 of Set 12 | douentza
# Processing Record 46 of Set 12 | esso
# Processing Record 47 of Set 12 | coos bay
# Processing Record 48 of Set 12 | bakchar
# Processing Record 49 of Set 12 | kununurra
# Processing Record 50 of Set 12 | praia da vitoria
# Processing Record 1 of Set 13 | les cayes
# Processing Record 2 of Set 13 | komsomolskiy
# Processing Record 3 of Set 13 | puerto quijarro
# Processing Record 4 of Set 13 | juegang
# Processing Record 5 of Set 13 | pachelma
# Processing Record 6 of Set 13 | shangrao
# Processing Record 7 of Set 13 | geraardsbergen
# Processing Record 8 of Set 13 | ginda
# Processing Record 9 of Set 13 | la ronge
# Processing Record 10 of Set 13 | greeneville
# Processing Record 11 of Set 13 | sambava
# Processing Record 12 of Set 13 | great bend
# Processing Record 13 of Set 13 | bakel
# Processing Record 14 of Set 13 | arandis
# Processing Record 15 of Set 13 | gumdag
# Processing Record 16 of Set 13 | deputatskiy
# Processing Record 17 of Set 13 | belaya gora
# Processing Record 18 of Set 13 | luanda
# Processing Record 19 of Set 13 | sooke
# Processing Record 20 of Set 13 | ketchikan
# Processing Record 21 of Set 13 | adigeni
# Processing Record 22 of Set 13 | pringsewu
# Processing Record 23 of Set 13 | kattivakkam
# Processing Record 24 of Set 13 | cabo san lucas
# Processing Record 25 of Set 13 | khani
# Processing Record 26 of Set 13 | shimoda
# Processing Record 27 of Set 13 | emba
# Processing Record 28 of Set 13 | kirakira
# Processing Record 29 of Set 13 | reidsville
# Processing Record 30 of Set 13 | sechura
# Processing Record 31 of Set 13 | syracuse
# Processing Record 32 of Set 13 | wufeng
# Processing Record 33 of Set 13 | itacarambi
# Processing Record 34 of Set 13 | conceicao do araguaia
# Processing Record 35 of Set 13 | batagay-alyta
# Processing Record 36 of Set 13 | kohima
# Processing Record 37 of Set 13 | envira
# Processing Record 38 of Set 13 | los llanos de aridane
# Processing Record 39 of Set 13 | halifax
# Processing Record 40 of Set 13 | panzos
# Processing Record 41 of Set 13 | penzance
# Processing Record 42 of Set 13 | namie
# Processing Record 43 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 44 of Set 13 | boyle
# Processing Record 45 of Set 13 | arroyo
# Processing Record 46 of Set 13 | goderich
# Processing Record 47 of Set 13 | launceston
# Processing Record 48 of Set 13 | alto longa
# Processing Record 49 of Set 13 | dalnerechensk
# Processing Record 50 of Set 13 | aloleng
# Processing Record 1 of Set 14 | doha
# Processing Record 2 of Set 14 | cochrane
# Processing Record 3 of Set 14 | boone
# Processing Record 4 of Set 14 | hanzhong
# Processing Record 5 of Set 14 | yar-sale
# Processing Record 6 of Set 14 | taga dzong
# City not found. Skipping...
# Processing Record 7 of Set 14 | guadalupe y calvo
# Processing Record 8 of Set 14 | jiroft
# City not found. Skipping...
# Processing Record 9 of Set 14 | alofi
# Processing Record 10 of Set 14 | ilinskiy
# Processing Record 11 of Set 14 | tres arroyos
# Processing Record 12 of Set 14 | gamboula
# Processing Record 13 of Set 14 | rivers
# Processing Record 14 of Set 14 | sisophon
# Processing Record 15 of Set 14 | kushima
# Processing Record 16 of Set 14 | pathein
# Processing Record 17 of Set 14 | aktash
# Processing Record 18 of Set 14 | axim
# Processing Record 19 of Set 14 | nanzhou
# Processing Record 20 of Set 14 | saint-augustin
# Processing Record 21 of Set 14 | oriximina
# Processing Record 22 of Set 14 | uhlove
# Processing Record 23 of Set 14 | pasni
# Processing Record 24 of Set 14 | irtyshskiy
# Processing Record 25 of Set 14 | mondlo
# Processing Record 26 of Set 14 | sabinopolis
# Processing Record 27 of Set 14 | ozgon
# City not found. Skipping...
# Processing Record 28 of Set 14 | nacala
# Processing Record 29 of Set 14 | borisoglebskiy
# Processing Record 30 of Set 14 | nedjo
# Processing Record 31 of Set 14 | baiyin
# Processing Record 32 of Set 14 | moca
# Processing Record 33 of Set 14 | terrace
# Processing Record 34 of Set 14 | dryden
# Processing Record 35 of Set 14 | coron
# Processing Record 36 of Set 14 | yaan
# Processing Record 37 of Set 14 | broken hill
# Processing Record 38 of Set 14 | tortoli
# Processing Record 39 of Set 14 | rio grande
# Processing Record 40 of Set 14 | toftir
# City not found. Skipping...
# Processing Record 41 of Set 14 | hirara
# Processing Record 42 of Set 14 | uspenka
# Processing Record 43 of Set 14 | touros
# Processing Record 44 of Set 14 | silveira
# Processing Record 45 of Set 14 | brawley
# Processing Record 46 of Set 14 | meulaboh
# Processing Record 47 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 48 of Set 14 | belyy yar
# Processing Record 49 of Set 14 | olot
# Processing Record 50 of Set 14 | haapu
# City not found. Skipping...
# Processing Record 1 of Set 15 | nuevo progreso
# Processing Record 2 of Set 15 | altay
# Processing Record 3 of Set 15 | doctor arroyo
# Processing Record 4 of Set 15 | leh
# Processing Record 5 of Set 15 | trincomalee
# Processing Record 6 of Set 15 | newala
# Processing Record 7 of Set 15 | vilhena
# Processing Record 8 of Set 15 | bac can
# City not found. Skipping...
# Processing Record 9 of Set 15 | namatanai
# Processing Record 10 of Set 15 | bara
# Processing Record 11 of Set 15 | dalbandin
# Processing Record 12 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 13 of Set 15 | neuquen
# Processing Record 14 of Set 15 | conceicao do mato dentro
# Processing Record 15 of Set 15 | cabedelo
# Processing Record 16 of Set 15 | yate
# Processing Record 17 of Set 15 | nexo
# Processing Record 18 of Set 15 | pitimbu
# Processing Record 19 of Set 15 | tuatapere
# Processing Record 20 of Set 15 | kalivia
# Processing Record 21 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 22 of Set 15 | keetmanshoop
# Processing Record 23 of Set 15 | mao
# Processing Record 24 of Set 15 | peniche
# Processing Record 25 of Set 15 | long xuyen
# Processing Record 26 of Set 15 | husavik
# Processing Record 27 of Set 15 | waddan
# Processing Record 28 of Set 15 | leskolovo
# Processing Record 29 of Set 15 | pimentel
# Processing Record 30 of Set 15 | caconda
# Processing Record 31 of Set 15 | ginir
# Processing Record 32 of Set 15 | piacabucu
# Processing Record 33 of Set 15 | makariv
# Processing Record 34 of Set 15 | castelldefels
# Processing Record 35 of Set 15 | sungaipenuh
# Processing Record 36 of Set 15 | voyvozh
# Processing Record 37 of Set 15 | hami
# Processing Record 38 of Set 15 | sorland
# Processing Record 39 of Set 15 | lata
# Processing Record 40 of Set 15 | pachperwa
# Processing Record 41 of Set 15 | canton
# Processing Record 42 of Set 15 | alexandria
# Processing Record 43 of Set 15 | zhoucheng
# Processing Record 44 of Set 15 | matay
# Processing Record 45 of Set 15 | nadym
# Processing Record 46 of Set 15 | suratgarh
# Processing Record 47 of Set 15 | chicama
# Processing Record 48 of Set 15 | warrnambool
# Processing Record 49 of Set 15 | bereda
# Processing Record 50 of Set 15 | daru
# Processing Record 1 of Set 16 | omsukchan
# Processing Record 2 of Set 16 | arlit
# Processing Record 3 of Set 16 | bosobolo
# Processing Record 4 of Set 16 | cankuzo
# Processing Record 5 of Set 16 | sakhipur
# Processing Record 6 of Set 16 | cooma
# Processing Record 7 of Set 16 | la ciotat
# Processing Record 8 of Set 16 | belmonte
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rikitea      PF -23.1203 -134.9692     78.64        73          47
# 1          Lompoc      US  34.6391 -120.4579     67.14        52           0
# 2          Albany      US  42.6001  -73.9662     21.16        62          25
# 3            Hilo      US  19.7297 -155.0900     73.62        88          37
# 4    Saint George      US  37.1041 -113.5841     52.36        30           0
# ..            ...     ...      ...       ...       ...       ...         ...
# 696       Cankuzo      BI  -3.1333   30.5833     59.09        91         100
# 697      Sakhipur      BD  24.3000   90.1833     64.27        64          10
# 698         Cooma      AU -36.2333  149.1333     49.77       100          75
# 699     La Ciotat      FR  43.1748    5.6045     55.81        73          45
# 700      Belmonte      BR -15.8631  -38.8828     82.90        64          85
#
#      Wind Speed   Current Description
# 0         12.33      scattered clouds
# 1          6.91             clear sky
# 2          1.99      scattered clouds
# 3          1.01      scattered clouds
# 4          1.01             clear sky
# ..          ...                   ...
# 696        1.63       overcast clouds
# 697        5.08             clear sky
# 698        4.61         broken clouds
# 699       12.86      scattered clouds
# 700        8.25  heavy intensity rain
#
# [701 rows x 9 columns]

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
